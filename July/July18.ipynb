# %% [markdown]
# # Uses 'SampleData2.csv'

# %%
import pandas as pd
import numpy as np
import plotly.express as px
import matplotlib.pyplot as plt

data = pd.read_csv("SampleData2.csv")
data
# Out:
#      SubjID  Decision1  Bias1  Decision2  Bias2  Decision3  Bias3  \
# 0         1          0      1          5      1          2      1
# 1         2          3      1          3      1          0      1
# 2         3          1      0          5      0          1      0
# 3         4          4      0          4      1          5      1
# 4         5          4      0          2      1          1      1
# ..      ...        ...    ...        ...    ...        ...    ...
# 195     196          3      0          0      0          3      0
# 196     197          4      0          3      1          1      1
# 197     198          1      1          2      0          0      0
# 198     199          2      0          4      0          3      0
# 199     200          2      0          4      0          0      0
#
#      HealthStatus
# 0              85
# 1              75
# 2              95
# 3              80
# 4              95
# ..            ...
# 195            75
# ...

# %%
subjID_list = data["SubjID"].values.tolist()
d1_list = data["Decision1"].values.tolist()
d2_list = data["Decision2"].values.tolist()
d3_list = data["Decision3"].values.tolist()
health_list = data["HealthStatus"].values.tolist()

# %%
# create data
A = np.array(d1_list[:10]) #np.array([3,6,9,4,2,5])
B = np.array(d2_list[:10]) #np.array([2,8,1,9,7,3])
X = np.arange(10)
 
# plot the bars
plt.barh(X, A, color = 'r')
plt.barh(X, -B, color = 'b')
plt.title("Back-to-Back Bar Chart")
plt.show()
