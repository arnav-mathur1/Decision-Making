# %% [markdown]
# # Uses 'JointEvaluation.csv'

# %%
import pandas as pd
import numpy as np
import plotly.express as px

print("Pick one of the four: Decision1, Decision2, Decision3, HealthStatus")
user = input("Enter:")

data = pd.read_csv("JointEvaluation.csv")
fig = px.parallel_categories(data, title="Joint Evaluation", color = user
        , color_continuous_scale=px.colors.sequential.Viridis)
fig.show()
# Out:
# Pick one of the four: Decision1, Decision2, Decision3, HealthStatus
# Enter: HealthStatus
