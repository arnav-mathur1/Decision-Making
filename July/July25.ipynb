# %%
from tkinter import *
# create a GUI window widget
window=Tk()
# create an inner window
cv =Canvas(window,width=500,height=500)
cv.pack()
# create a rectangle
cv.create_rectangle(50,20,200,200,fill="blue")

window.mainloop()

# %%
from tkinter import *   

tkWindow = Tk()  
tkWindow.geometry('400x150')  
tkWindow.title('PythonExamples.org - Tkinter Example')
  
button = Button(tkWindow, text = 'Submit', bg='#ffffff', activebackground='#00ff00')  
button.pack()  
  
tkWindow.mainloop()

# %%
from tkinter import *   
class OneSquare():
    def __init__(self, can, start_x, start_y, size):
        self.can=can
        self.id = self.can.create_rectangle((start_x, start_y,
                  start_x+size, start_y+size), fill="blue")
        self.can.tag_bind(self.id, "<ButtonPress-1>", self.set_color)

        self.color_change=True

    def set_color(self, event=None):
        self.color_change = not self.color_change
        color="blue"
        if not self.color_change:
            color="red"
        self.can.itemconfigure(self.id, fill=color)

root = Tk()
canvas = Canvas(root)
canvas.grid(column=1, row=1, sticky=(N, S, E, W))

OS1=OneSquare(canvas, 1, 1, 60)
OS2=OneSquare(canvas, 90, 1, 30)
OS3=OneSquare(canvas, 1, 90, 90)
OS4 = OneSquare(canvas, 150, 90, 30)

#Button(root, text="Exit", bg="orange",
#       command=root.quit).grid(row=2)

root.mainloop()
